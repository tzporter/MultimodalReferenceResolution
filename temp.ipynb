# %%
import numpy as np

# %%
X = np.load("selected_poses/poses_file-ch07_frames-5176-5239_present-True.npy")
X = X[:,:,:2]
count = 0
for frame in range(X.shape[0]-1):
    # np.max(np.abs(X[frame] - X[frame+1])) < .5_
    # if np.max(np.abs(X[frame] - X[frame+1])) < .4 :
    if np.max(np.abs(X[frame][0] - X[frame+1][0])) < .1 :
        count += 1
        # print(X[frame])
        # print(X[frame+1])
        # print("_"*20)
#     # print(np.array_equal(X[frame], X[frame+1]))
print(count)
# Out:
# 35

# %%
X.shape[0]*20/50
# Out:
# 25.2
